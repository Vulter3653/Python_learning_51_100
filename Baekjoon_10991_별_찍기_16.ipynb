# %% [markdown]
# <a href="https://colab.research.google.com/github/Vulter3653/Python_learning_51_100/blob/main/Baekjoon_10991_%EB%B3%84_%EC%B0%8D%EA%B8%B0_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input())
for a in range(x):
  x -= 1
  print(' '*x+'*'+' *'*a)
# Out:
# 120
#                                                                                                                        *
#                                                                                                                       * *
#                                                                                                                      * * *
#                                                                                                                     * * * *
#                                                                                                                    * * * * *
#                                                                                                                   * * * * * *
#                                                                                                                  * * * * * * *
# ...

# %%
import sys
x = int(sys.stdin.readline().rstrip())
for a in range(x):
  x -= 1
  print(' '*x+'*'+' *'*a)
